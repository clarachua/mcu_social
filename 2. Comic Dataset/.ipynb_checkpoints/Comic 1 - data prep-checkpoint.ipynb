# %%
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# this is just the original hero network file
# we group by to get the duplicate count
data1 = pd.read_csv("hero-networkA.csv")
data1 = data1.groupby(['hero1','hero2']).size().reset_index()
data1.rename(columns = {0: 'weight'}, inplace = True)

# this is the file with column switched
data2 = pd.read_csv("hero-networkB.csv")
data2 = data2.groupby(['hero1','hero2']).size().reset_index()
data2.rename(columns = {0: 'weight'}, inplace = True)

# %%
# we concat to one list
dataAll = pd.concat([data1, data2])

# %%
# we group again so that example A-B and B-A will all add to weights
dataAll = dataAll.groupby(['hero1','hero2']).agg({'weight': np.sum}).reset_index()
dataAll.rename(columns = {0: 'weight'}, inplace = True)

# %%
dataAll.sort_values(by=['weight'], ascending=False)
# Out:
#                        hero1                 hero2  weight
# 213085     PATRIOT/JEFF MACE     PATRIOT/JEFF MACE    2550
# 186598  MISS AMERICA/MADELIN     PATRIOT/JEFF MACE    1894
# 213083     PATRIOT/JEFF MACE  MISS AMERICA/MADELIN    1894
# 186594  MISS AMERICA/MADELIN  MISS AMERICA/MADELIN    1344
# 292584  THING/BENJAMIN J. GR  HUMAN TORCH/JOHNNY S     744
# 128312  HUMAN TORCH/JOHNNY S  THING/BENJAMIN J. GR     744
# 193246  MR. FANTASTIC/REED R  HUMAN TORCH/JOHNNY S     713
# 127900  HUMAN TORCH/JOHNNY S  MR. FANTASTIC/REED R     713
# 292879  THING/BENJAMIN J. GR  MR. FANTASTIC/REED R     708
# 193967  MR. FANTASTIC/REED R  THING/BENJAMIN J. GR     708
# 133817  INVISIBLE WOMAN/SUE   MR. FANTASTIC/REED R     701
# 193273  MR. FANTASTIC/REED R  INVISIBLE WOMAN/SUE      701
# 133555  INVISIBLE WOMAN/SUE   HUMAN TORCH/JOHNNY S     694
# 127641  HUMAN TORCH/JOHNNY S  INVISIBLE WOMAN/SUE      694
# 134202  INVISIBLE WOMAN/SUE   THING/BENJAMIN J. GR     668
# 292610  THING/BENJAMIN J. GR  INVISIBLE WOMAN/SUE      668
# 270827  SPIDER-MAN/PETER PAR  WATSON-PARKER, MARY      616
# 319412  WATSON-PARKER, MARY   SPIDER-MAN/PETER PAR     616
# 269883  SPIDER-MAN/PETER PAR     JAMESON, J. JONAH     526
# 140646     JAMESON, J. JONAH  SPIDER-MAN/PETER PAR     526
# 42923        CAPTAIN AMERICA  IRON MAN/TONY STARK      446
# 136312  IRON MAN/TONY STARK        CAPTAIN AMERICA     446
# 250125  SCARLET WITCH/WANDA                VISION      422
# 313043               VISION   SCARLET WITCH/WANDA      422
# 7698    ANT-MAN/DR. HENRY J.  WASP/JANET VAN DYNE      406
# 316964  WASP/JANET VAN DYNE   ANT-MAN/DR. HENRY J.     406
# 177167  MARVEL GIRL/JEAN GRE  CYCLOPS/SCOTT SUMMER     390
# 64785   CYCLOPS/SCOTT SUMMER  MARVEL GIRL/JEAN GRE     390
# 327515      WOLVERINE/LOGAN   STORM/ORORO MUNROE S     389
# 279060  STORM/ORORO MUNROE S      WOLVERINE/LOGAN      389
# ...                      ...                   ...     ...
# 145719         JOSEPH, SHEVA             LEVITICUS       1
# 145661                JOSEPH           PAGE, KAREN       1
# 145656                JOSEPH  NELSON, FRANKLIN FOG       1
# 145654                JOSEPH  MR. SINISTER/NATHAN        1
# 145620                JOSEPH       HURDLER, THOMAS       1
# 145602                JOSEPH     FALCON/SAM WILSON       1
# 145604                JOSEPH       FITZROY, TREVOR       1
# 145605                JOSEPH                 FORGE       1
# 145607                JOSEPH    GAMESMASTER/JEREMY       1
# 145608                JOSEPH          GLADIATOR II       1
# 145609                JOSEPH               GOG III       1
# 145610                JOSEPH  GREEN GOBLIN/NORMAN        1
# 145612                JOSEPH   GYRICH, HENRY PETER       1
# 145614                JOSEPH           HARRAS, BOB       1
# 145617                JOSEPH  HERCULES [GREEK GOD]       1
# 145618                JOSEPH  HULK/DR. ROBERT BRUC       1
# 145625                JOSEPH  IRON MAN/TONY STARK        1
# 145652                JOSEPH  MILLER, STACI MURPHY       1
# 145627                JOSEPH  JAMESON, MARLA MADIS       1
# 145628                JOSEPH        JARVIS, EDWIN        1
# 145631                JOSEPH  KA-ZAR/KEVIN PLUNDER       1
# 145635                JOSEPH    KLEINSTOCK, HARLAN       1
# 145636                JOSEPH      KLEINSTOCK, SVEN       1
# 145637                JOSEPH       LANDSCAPE/BRETT       1
# 145640                JOSEPH  LUMPKIN, WILLIAM WIL       1
# 145641                JOSEPH  MACTAGGERT, MOIRA KI       1
# 145644                JOSEPH              MAGOG II       1
# 145648                JOSEPH  MASTERMIND/JASON WYN       1
# 145651                JOSEPH         MILLER, CHRIS       1
# 334425                 ZZZAX  WONDER MAN/SIMON WIL       1
#
# [334426 rows x 3 columns]

# %%
# realised that the edgelist function does not care the order of nodes.
# A-B and B-A is the same to it. So it will take the latest copy it finds.
# therefore duplicates will be ignored, and the latest copy with correct weight forms the graph
g = nx.from_pandas_edgelist(dataAll, 'hero1', 'hero2', edge_attr=True)

# %%
# how to get weight of one pair relationship
g['ZZZAX']['WONDER MAN/SIMON WIL']['weight']
# Out:
# 1

# %%
# number of nodes = no of unique characters
len(g)
# Out:
# 6426

# %%
nx.write_gexf(g, "graph.gexf")

# %%
sorted(list(g.nodes()))
# Out:
# ['24-HOUR MAN/EMMANUEL',
#  '3-D MAN/CHARLES CHAN',
#  '4-D MAN/MERCURIO',
#  '8-BALL/',
#  'A',
#  "A'YIN",
#  'ABBOTT, JACK',
#  'ABCISSA',
#  'ABEL',
#  'ABOMINATION | MUTANT',
#  'ABOMINATION/EMIL BLO',
#  'ABOMINATRIX',
#  'ABRAXAS',
#  'ABSALOM',
#  'ABSORBING MAN | MUTA',
#  'ABSORBING MAN/CARL C',
#  'ACBA',
#  'ACHEBE, REVEREND DOC',
#  'ACHILLES',
#  'ACHILLES II/HELMUT',
#  'ACROBAT/CARL ZANTE',
#  'ADAM 3,031',
#  'ADAM X',
#  'ADAMS, CINDY',
#  'ADAMS, CONGRESSMAN H',
#  'ADAMS, GEORGE',
#  'ADAMS, MARTHA',
#  'ADAMS, NICOLE NIKKI',
#  'ADAMSON, JASON',
#  'ADAMSON, REBECCA',
#  'ADMIRAL PROTOCOL/',
#  'ADORA',
#  'ADORA CLONE',
#  'ADRIA',
#  'ADVA',
#  'ADVENT/KYLE GROBE',
#  'ADVERSARY',
#  'AEGIS/TREY ROLLINS',
#  'AENTAROS',
#  'AFTERLIFE',
#  'AGAMEMNON',
#  'AGAMEMNON II/ANDREI ',
#  'AGAMEMNON III/',
#  'AGAMOTTO',
#  'AGARN, CAPT.',
#  'AGED GENGHIS',
#  'AGEE, DR. AUBREY',
#  'AGEE, REBECCA',
#  'AGENT 18/JACK TRUMAN',
#  'AGENT AXIS/',
#  'AGENT-X/',
#  'AGGAMON',
#  'AGINAR',
#  'AGON',
#  'AGONY/',
#  'AGUIRRE, ISOBEL',
#  'AHAB/RORY CAMPBELL',
#  'AHQLAU',
#  'AHURA',
#  'AI-CHIA',
#  'AINET',
#  'AIR WALKER/ARLO SAMU',
#  'AIR-WALKER/GABRIEL L',
#  'AIRBORNE/',
#  'AIREO/AEOLUS [INHUMA',
#  'AJAK/TECUMOTZIN [ETE',
#  'AJAX',
#  'AJAX II',
#  "AJES'HA",
#  'AKAFE',
#  'AKULIA',
#  'AKUTAGAWA, OSAMU',
#  'AL-KHALAD',
#  'ALANYA',
#  'ALBERIK',
#  'ALBERT',
#  'ALBINO/DR. AUGUSTA S',
#  'ALBUQUERQUE, JEREMIA',
#  'ALCHEMY/THOMAS JONES',
#  'ALDEN, PROF. MEREDIT',
#  'ALEGRIA, RICHIE',
#  'ALEXANDER, CALEB',
#  'ALEXANDER, CARRIE',
#  'ALFY',
#  'ALIOTH',
#  'ALIST',
#  'ALISTRO',
#  'ALLEN, TERRY',
#  'ALOUETTE, GENARD',
#  'ALPHA',
#  'ALRAUNE, MARLENE',
#  'ALVAREZ, CARLY',
#  'ALVAREZ, FELIX',
#  'ALVAREZ, PAUL',
#  'AMAZO-MAXI-WOMAN/',
#  'AMAZON',
#  'AMENHOTEP',
#  'AMERICAN EAGLE II/JA',
#  'AMERICAN EAGLE III/J',
#  'AMERICAN SAMURAI/',
#  'AMERICOP/',
#  'AMIKO',
#  'AMINEDI',
#  'AMPERE/',
#  'AMPHARON',
#  'AMPHIBIAN/KINGLEY RI',
#  'AMPHIBIUS',
#  'ANACONDA/BLANCHE SIT',
#  'ANAIS',
#  'ANAK',
#  'ANALYZER',
#  'ANAMI, HIROSHI',
#  'ANANASTASIA/ANNA',
#  'ANARCHIST/TIKE ALICA',
#  'ANCESTOR/',
#  'ANCIENT ONE',
#  'ANCIENT ONE/BARON MO',
#  'ANDERS, JOSHUA RICHI',
#  'ANDERSON, BAXTER',
#  'ANDERSON, CHARLES',
#  'ANDERSON, CHET',
#  'ANDERSON, CHIEF MAGI',
#  'ANDERSON, GINA',
#  'ANDERSON, MARJORIE',
#  'ANDERSON, NICKY',
#  'ANDERSSEN, TANYA',
#  'ANDREWS, DARYL TROOP',
#  'ANDROMEDA/ANDROMEDA ',
#  'ANDROS',
#  'ANDWELLA',
#  'ANELLE',
#  'ANGAR THE SCREAMER/D',
#  'ANGEL 2013',
#  'ANGEL DOPPELGANGER',
#  'ANGEL II/THOMAS HALL',
#  'ANGEL III/HALLOWAY',
#  'ANGEL IV',
#  'ANGEL/WARREN KENNETH',
#  'ANGELOPOULOS, ANGEL ',
#  'ANGKOR',
#  'ANGLER',
#  'ANGSTROM, EARL',
#  'ANIELLE',
#  'ANIMATOR II/',
#  'ANIMATOR/DR. FREDRIC',
#  'ANIMUS',
#  'ANNALEE',
#  'ANNIHILUS',
#  'ANOMALY',
#  'ANOMALY III',
#  'ANON, LORD',
#  'ANSWER',
#  'ANSWER II/DAVID FERR',
#  'ANT-MAN II/SCOTT HAR',
#  'ANT-MAN/DR. HENRY J.',
#  'ANTEUS',
#  'ANTHROMORPHO',
#  'ANTI-PHOENIX',
#  'ANTI-VISION',
#  'ANTIBODY',
#  'ANTIQUARY/',
#  'ANTOINETTE, MARIE',
#  'ANTORO',
#  'ANTRO',
#  'ANUBAR, ANWAR',
#  'ANUBIA',
#  'ANVIL/JOHNNY ANVIL',
#  'APE MAN II/ROY MCVEY',
#  'APE MAN/GORDON MONK ',
#  'APE-X/XINA',
#  'APE/',
#  'APOCALYPSE | MUTANT ',
#  'APOCALYPSE/EN SABAH ',
#  'APOCRYPHUS',
#  'APOLLO [GREEK GOD]',
#  'APOSTATE',
#  'APPALLA',
#  'APPLEBAUM, PHANTASY',
#  'AQUARIAN/WUNDARR',
#  'AQUARIUS II/',
#  'AQUARIUS III/',
#  'AQUARIUS/DARREN BENT',
#  'ARABIAN KNIGHT/ABDUL',
#  'ARACHNE',
#  'ARAGORN',
#  'ARAKI II',
#  "ARAKI [SHI'AR]",
#  'ARBOGAST, BAMBI',
#  'ARCADE/',
#  'ARCADIUS',
#  'ARCANNA/ARCANNA JONE',
#  'ARCHAEOPTERYX/TONAJA',
#  'ARCHER, ULYSSES SAMS',
#  'ARCHER/JUDE BLACK',
#  'ARCLIGHT/PHILLIPA SO',
#  'ARCTURUS',
#  'ARES [GREEK GOD]',
#  'AREX',
#  'ARGOS',
#  'ARGOSY, HERVE',
#  'ARIA',
#  'ARIANE',
#  'ARIDES',
#  'ARIEL II',
#  'ARIES II/GROVER RAYM',
#  'ARIES III/',
#  'ARIES/MARCUS LASSITE',
#  'ARISHEM [CELESTIAL]',
#  'ARIZE',
#  'ARKANIAN, GLIB',
#  'ARKO',
#  'ARKON',
#  'ARLINGTON, DR. MARCU',
#  'ARLISSE',
#  'ARMADA',
#  'ARMADA II/',
#  'ARMADILLO/ANTONIO RO',
#  'ARMAGEDDON',
#  'ARMAGEDDON MAN',
#  'ARMAND',
#  'ARMAROS',
#  'ARMAZIEL',
#  'ARMBRUSTER, COLONEL ',
#  'ARMS MERCHANT/ANDREA',
#  'ARMSTRONG, ?',
#  'ARMSTRONG, MYRA',
#  'ARNSTROM',
#  'ARON [WATCHER]',
#  'ARRANGER/',
#  'ARROW',
#  'ARSENAL',
#  'ARSENAL II',
#  'ARSENIC',
#  'ARTEMIS',
#  'ARVAK',
#  'ARYAN',
#  'ASANO',
#  'ASBERY, SHAMARI',
#  'ASBESTOS LADY',
#  'ASH, BRANDY',
#  'ASHEMA [CELESTIAL]',
#  'ASHER, CARL',
#  'ASHER, DONNA',
#  'ASHER, MICHAEL',
#  'ASHUR',
#  'ASKANI',
#  'ASMODEUS',
#  'ASP II/CLEO',
#  'ASSAULT/',
#  'ASTARTE',
#  'ASTER, LUCIAN',
#  'ASTRA',
#  'ASTRA II',
#  'ASTROLOGER/',
#  'ASTRONOMER',
#  'ASTROVIK, ARNOLD',
#  'ASTROVIK, NORMA',
#  'ASYLUM II/HENRIQUE M',
#  'ASYLUM/',
#  'ATALANTA',
#  'ATALON',
#  'ATHENA [GREEK GOD]',
#  'ATKINSON, MAJ. EDMON',
#  'ATLAS',
#  'ATLAS III',
#  'ATOM SMASHER II/',
#  'ATOM SMASHER/',
#  'ATOM-SMASHER/',
#  'ATOR, GENERAL',
#  'ATTRACTIVE LAD/AUNDR',
#  'ATTUMA',
#  'AUGUST PERSONAGE IN ',
#  'AUNTIE FREEZE/',
#  'AURA/ANN HERD',
#  'AURIC/',
#  'AURORA DOPPELGANGER',
#  'AURORA | MUTANT X-VE',
#  'AURORA/JEANNE-MARIE ',
#  'AUSTIN, GEN.',
#  'AUSTIN, SUSAN',
#  'AUSTIN, TERRY',
#  'AUTHIER, POLICE CHIE',
#  'AUTHIER, TRACY TRACE',
#  'AUTHORITY/',
#  'AUTOLYCUS',
#  'AVALANCHE/DOMINIC PE',
#  'AVANDALIA',
#  'AVATAR',
#  'AVATAR II/PRINCESS A',
#  'AVIA',
#  'AVIOS',
#  'AVIUS',
#  'AVRIL, SALLY',
#  'AVRIL, YVETTE',
#  'AWESOME ANDROID',
#  'AXE/',
#  'AXIS/',
#  'AYALA, AWILDA',
#  'AYALA, FILIPPO',
#  'AYALA, MRS.',
#  'AYALA, NESTOR',
#  'AYESHA',
#  'AZAZEL',
#  'AZAZEL II',
#  'AZIR',
#  'AZOPARDI',
#  'AZOR',
#  'AZRAEL',
#  'AZURE',
#  "B'ARR",
#  "B'GON",
#  "B'KOSA, GEN. JONATHA",
#  'BAAL',
#  'BAAL II',
#  'BACILLUS',
#  'BADALAMENTE, JESUS',
#  'BADALINO, LT. MICHAE',
#  'BAILEY, GAILYN',
#  'BAILEY, JOEY',
#  'BAILEY, SARA GREY',
#  'BAIRD, DR.',
#  'BAKER',
#  'BAKER, ANNE-MARIE',
#  'BALABAN/',
#  'BALDER [ASGARDIAN]',
#  'BALDWIN, JUSTIN',
#  'BALDWIN, MADELYNE MA',
#  'BALE, EMERSON',
#  'BALLANTINE, DEVON',
#  'BALLANTINE, KAYLA',
#  'BALLANTINE, MR.',
#  'BALLANTINE, MRS.',
#  'BALOR',
#  'BAMBI',
#  'BANCROFT, MARTINE',
#  'BANDIT/',
#  'BANK, IRVING',
#  'BANKS, SHARON',
#  'BANNER, BETTY ROSS T',
#  'BANNERJEE, DR.',
#  'BANNON, LANCE',
#  'BANSHEE 2013',
#  'BANSHEE II',
#  'BANSHEE/SEAN CASSIDY',
#  'BANTAM/',
#  'BANTOCK, LT. OLIVER',
#  'BAPTISTE, TANTE MATT',
#  'BARAK',
#  'BARBAROSSA, MARIO',
#  'BARBAROSSA, VINNIE',
#  'BARBARUS',
#  'BARIUM',
#  'BARKER',
#  'BARKER, MATTHEW T.',
#  'BARNACLE/',
#  'BARNETT, MIKE',
#  'BARON BLOOD II/VICTO',
#  'BARON BLOOD/JOHN FAL',
#  'BARON BRIMSTONE/',
#  'BARON MACABRE/',
#  'BARON MORDO/KARL MOR',
#  'BARON SAMEDI',
#  'BARON STRUCKER/WOLFG',
#  'BARON ZEBEK',
#  'BARONESS ZEMO/HEIKE',
#  'BARRACUDA/',
#  'BARRAGE',
#  'BARRANCO, MARIA ESME',
#  'BARRENOS, OMAR',
#  'BARRIER/',
#  'BARRINGTON',
#  'BARRON, RICK',
#  'BARROWS, WALTER',
#  'BARTLETT, STU',
#  'BARTON, SEN.',
#  'BARTOS',
#  'BASALLO/LAVA MEN KIN',
#  'BASALTAR',
#  'BASILISK II',
#  'BASILISK III/',
#  'BASILISK/BASIL ELKS',
#  'BATAL/',
#  'BATROC/GEORGES BATRO',
#  'BATTERING RAM',
#  'BATTERY/',
#  'BATTLE, MONTGOMERY',
#  'BATTLEAXE II/JEROME ',
#  'BATTLEAXE/',
#  'BATTLESTAR/LEMAR HOS',
#  'BATWING/',
#  'BAV-TEK',
#  'BAXTER',
#  'BAXTER, ABIGAIL',
#  'BAXTER, NOAH',
#  'BAYLOR, FRANK',
#  'BAYMAX',
#  'BAZIN, ALLEGRA',
#  'BAZIN, ANDREW',
#  'BAZIN, BRODERICK RIC',
#  'BAZIN, PHILLIPPE',
#  'BEACH, GINGER',
#  'BEACH, SPIDER',
#  'BEALE, ERIC',
#  'BEAR/',
#  'BEAST 2013',
#  'BEAST DOPPELGANGER',
#  'BEAST DOPPELGANGER I',
#  'BEAST/HENRY &HANK& P',
#  'BEAUMONT, SPENCER',
#  'BEAUTIFUL DREAMER',
#  'BEAUTIFUL DREAMER II',
#  'BEAUTY',
#  'BECKFORD, NOEL',
#  'BECKLEY, BENNY',
#  'BECKMAN, CHARLES',
#  'BECKMAN, JOSEPH',
#  'BECKMAN, LISA',
#  'BECKMAN, SARAH',
#  'BEDFORD, BRAD HULK',
#  'BEDLAM II/OLISA KABA',
#  'BEDLAM/JESSE AARONSO',
#  'BEEF/',
#  'BEEFER',
#  'BEERE, JASON',
#  'BEETLE II/LEILA DAVI',
#  'BEETLE ROBOT',
#  'BEETLE/ABNER RONALD ',
#  'BEHEMOTH',
#  'BEL-DANN, GEN.',
#  'BELASCO',
#  'BELDAME',
#  'BELGRADE, DR. HORATI',
#  'BELIAL',
#  'BELL, HERBERT',
#  'BELLADONNA',
#  'BELLAM',
#  'BELLE',
#  'BENAZA',
#  'BENCHLEY',
#  'BENDIX, DR. ALBERT',
#  'BENEDICT',
#  'BENEDICT, ANDREW',
#  'BENGAL/',
#  'BENJAMIN, BYRON',
#  'BENNETT, DANNY',
#  'BENNETT, MITCH',
#  'BENNING, VERONICA',
#  'BENNY, JAKE',
#  'BENTLEY, MILES',
#  'BENTLEY, VICTORIA',
#  'BENTON, TERRY',
#  'BENWAY, DR.',
#  'BERDITCHEV, ITZHAK',
#  'BEREET',
#  'BERENGHETTI, MICHAEL',
#  'BERENGHETTI, SUSAN',
#  'BERGER, PROF.',
#  'BERGIER, REBECCA',
#  'BERGLUND, GEN.',
#  'BERKELEY, TRAVIS',
#  'BERMAN, ADAM',
#  'BERNARD THE POET',
#  'BERNHARD, CLARICE',
#  'BERNIE',
#  'BERNSTEIN, DR. NOAH',
#  'BERNSTEIN, EMMA WEBS',
#  'BERSERKER',
#  'BERSERKER III',
#  'BERTRAM',
#  'BERYL',
#  'BERYLLIUM',
#  'BETA RAY BILL',
#  'BETA RAY BILL | MUTA',
#  'BETELHEIM, NORMA',
#  'BETTY-6',
#  'BEVATRON/',
#  'BEYNON, DR. BRADLEY',
#  'BEYONDER',
#  'BEYONDER | MUTANT X-',
#  'BI-BEAST',
#  'BI-BEAST II',
#  'BIANDU',
#  'BIG BEN/',
#  'BIG BERTHA/ASHLEY CR',
#  'BIG CASINO/',
#  'BIG MAN/FREDERICK FO',
#  'BIG ONE/KENJIRO SASA',
#  'BIGGERS, MELVIN',
#  'BILE/',
#  'BILLUPS, AGENT',
#  'BINARY | MUTANT X-VE',
#  'BINARY/CAROL DANVERS',
#  'BIOHAZARD',
#  'BIOHAZARD II/FLETCHE',
#  'BIRD MAN III/',
#  'BIRD MAN/HENRY HAWK',
#  'BIRD, TUESDAY',
#  'BIRDBRAIN',
#  'BIRDY',
#  'BISHOP /',
#  'BISON/BILLY KITSON',
#  'BITMAP/',
#  'BIZEN',
#  'BLACK AVENGER/JERRY ',
#  'BLACK BOLT | MUTANT ',
#  'BLACK BOLT/BLACKANTO',
#  'BLACK BRIGADE',
#  'BLACK CAT/FELICIA HA',
#  'BLACK CRANE/',
#  'BLACK CROW/JESSE BLA',
#  'BLACK DEATH/DR. IVAN',
#  'BLACK FOX II/',
#  'BLACK FOX/ROBERT W. ',
#  'BLACK GOLIATH/DR. WI',
#  'BLACK HOLE/MORTON KI',
#  'BLACK KING/SEBASTIAN',
#  'BLACK KNIGHT II/SIR ',
#  'BLACK KNIGHT III/EOB',
#  'BLACK KNIGHT IV DOPP',
#  'BLACK KNIGHT IV/PROF',
#  'BLACK KNIGHT V DOPPE',
#  'BLACK KNIGHT V STATU',
#  'BLACK KNIGHT V/DANE ',
#  'BLACK KNIGHT VI/PROF',
#  'BLACK KNIGHT/SIR PER',
#  'BLACK LAMA',
#  'BLACK MAMBA/TANYA SE',
#  'BLACK MARIAH',
#  'BLACK MARVEL/DAN LYO',
#  'BLACK MORAY',
#  'BLACK MOUNTAIN/KUROY',
#  'BLACK PANTHER | MUTA',
#  "BLACK PANTHER/T'CHAL",
#  'BLACK RAAZER/',
#  'BLACK RACER/',
#  'BLACK RAZER',
#  'BLACK SPECTRE/CARSON',
#  'BLACK TALON II/SAMUE',
#  'BLACK TALON III',
#  'BLACK TALON/DESMOND ',
#  'BLACK TARANTULA II/C',
#  'BLACK TARANTULA/LAMU',
#  'BLACK TOM CASSIDY',
#  'BLACK WIDOW DOPPELGA',
#  'BLACK WIDOW II/YELEN',
#  'BLACK WIDOW | MUTANT',
#  'BLACK WIDOW/NATASHA ',
#  'BLACK, CAL',
#  'BLACK, CYRUS',
#  'BLACK, RACHEL',
#  'BLACKBALL',
#  'BLACKBIRD/',
#  'BLACKBODY',
#  'BLACKHEART',
#  'BLACKJACK/',
#  'BLACKOUT II/',
#  'BLACKOUT/MARCUS DANI',
#  'BLACKSHEAR, JONAS',
#  'BLACKWELL',
#  'BLACKWING II/',
#  'BLACKWING/JOSEPH MAN',
#  'BLACKWOOD, JENNY',
#  'BLACKWULF',
#  'BLADE',
#  'BLAIR, CALEY',
#  'BLAIRE, CARTER',
#  'BLAKE, BECKY',
#  'BLAKE, DR. DONALD',
#  'BLAKE, DR. DONALD (C',
#  'BLAKE, EMILY',
#  'BLAKE, KENT',
#  'BLANDING, ANDREW',
#  'BLANDING, HALEY',
#  'BLANDING, MRS.',
#  'BLAQUESMITH',
#  'BLASTAAR',
#  'BLASTING CAP/',
#  'BLAZE, CRAIG',
#  'BLAZE, EMMA',
#  'BLAZE, ROXANNE SIMPS',
#  'BLAZING SKULL/MARK T',
#  'BLESSING, MORGANA',
#  'BLIND AL/ALTHEA',
#  'BLINDSIDE II/BOBBI C',
#  'BLINK/FERGUSON, CLAR',
#  'BLISS',
#  'BLISS, BONNIE',
#  'BLISS, MISS',
#  'BLITZIANA',
#  'BLITZKRIEG/',
#  'BLIZZARD II/DONALD G',
#  'BLIZZARD/PROF. GREGO',
#  'BLOB/FRED J. DUKES',
#  'BLOCKADE/DEXTER PARI',
#  'BLOCKBUSTER II',
#  'BLOCKBUSTER III/MICH',
#  'BLOCKBUSTER/',
#  'BLOK',
#  'BLOKE/MICKEY TORK',
#  'BLOOD BROTHERS',
#  'BLOOD SPIDER/',
#  'BLOOD WRAITH/SEAN DO',
#  'BLOOD-TIDE',
#  'BLOODAXE/JACKIE LUKU',
#  'BLOODHOUND/',
#  'BLOODLUST',
#  'BLOODSCREAM',
#  'BLOODSHED/WYNDELL DI',
#  'BLOODSTONE/ULYSSES B',
#  'BLOODSTORM | MUTANT ',
#  'BLOODSTRIKE/ERIC CON',
#  'BLOODVESSEL, BUSTA',
#  "BLOODWING [SHI'AR]",
#  'BLOODWRAITH/SEAN DOL',
#  'BLOODY BESS',
#  'BLOODY MARY',
#  'BLOTT, BRIGADIER INK',
#  'BLOWTORCH/',
#  'BLUDGEON/',
#  'BLUE BULLET/PROF. JO',
#  'BLUE DIAMOND/PROFESS',
#  'BLUE SHIELD/JOSEPH J',
#  'BLUE STREAK/',
#  'BLUNT',
#  'BLUR',
#  'BLURRY',
#  'BOAK',
#  'BOBCAT/',
#  'BODYBAG',
#  'BOERKE, MAYOR',
#  'BOGATYR/MIKULA GOLUB',
#  'BOGGS, MORDECAI P.',
#  'BOLERO/',
#  'BOLT II/CHRIS BRADLE',
#  'BOLT, COUNCILMAN AND',
#  'BOLT/LAWRENCE EVANS',
#  'BOMBADIER/',
#  'BOMBLAST/',
#  'BOMBSHELL/',
#  'BOND',
#  'BONEBREAKER/',
#  'BONES/ELIZABETH BLIS',
#  'BONITA',
#  'BOOBYTRAP/',
#  'BOOKWORM/NELSON GRUB',
#  'BOOMER/TABITHA SMITH',
#  'BOOMERANG/FRED MYERS',
#  'BOOMSLANG/',
#  'BOONE',
#  'BORA',
#  'BORAKU',
#  'BORROB',
#  'BORROUGHS, CHARLES C',
#  'BOSCO, ELAINE',
#  'BOSHLOVOR',
#  'BOUDREAUX, BELLA DON',
#  'BOUDREAUX, MARIUS',
#  'BOULDER/',
#  'BOUNCER',
#  'BOUNTY',
#  'BOUNTY II',
#  'BOVA',
#  'BOWDEN, DENNIS',
#  'BOWEN, FATHER MICHAE',
#  'BOWMAN, MAJ.',
#  'BOX II/JERRY JAXXON',
#  'BOX IV/MADISON JEFFR',
#  'BOX/ROGER BOCHS',
#  'BOYD, TWO-FISTED TOM',
#  'BRADDOCK, ELIZABETH',
#  'BRADDOCK, JAMES',
#  'BRADDOCK, JAMES JR. ',
#  'BRADDOCK, JOHN',
#  'BRADLEY, CARRIE',
#  'BRADLEY, HANK',
#  'BRADLEY, JESSICA',
#  'BRAHAMS',
#  'BRAHMANES',
#  'BRAIN CELL/',
#  'BRAIN DRAIN/WERNER S',
#  'BRAINCHILD',
#  'BRAINSTORM/',
#  'BRAINY',
#  'BRAITHWAITE, JUDGE R',
#  'BRAMER',
#  'BRANDEIS, CAMMY',
#  'BRANDEIS, LIZ PARRIS',
#  'BRANDEIS, PROF. HENR',
#  'BRANDT, ELLEN',
#  'BRANNEX',
#  'BRANNEX, ALLESSANDRO',
#  'BRANSON',
#  'BRASS BISHOP/',
#  'BRASS/SEAN WATANABE',
#  'BRAWLER',
#  'BRAWN, HUNTER',
#  'BRAWN, TRISTAN',
#  'BREAKER/RAAK',
#  'BREEGAN',
#  'BRES',
#  'BREWER, AMY',
#  'BREWER, DR. MELINDA',
#  'BRICKFORD, CLAY',
#  'BRICKMAN, GLORIA',
#  'BRICKMAN, SEN. MILES',
#  'BRIDGE, GEORGE WASHI',
#  'BRIGGS, AGENT',
#  'BRIGGS, AGENT STEPHA',
#  'BRIGHTSWORD/CARTER D',
#  'BRIGHTWIND',
#  'BRINKE, NIOMI',
#  'BRIQUETTE/',
#  'BROADSIDE',
#  'BROGIN, BULL',
#  'BROKEN MAN',
#  'BROKER',
#  'BROMINE',
#  'BROMWELL, DR.',
#  'BRONA',
#  'BROOKS, ANNA',
#  'BROOP',
#  'BROTHER AXE',
#  'BROTHER CAESAR',
#  'BROTHER ROYAL',
#  'BROTHER STEPHEN',
#  'BROTHER TODE',
#  'BROTHER VIRGIL',
#  'BROTHER VOODOO | MUT',
#  'BROTHER VOODOO/DANIE',
#  'BROTHER WONDERFUL/DR',
#  'BROTHERS GRIMM',
#  'BROTHERS GRIMM II/BA',
#  'BROWN, ABE',
#  'BROWN, FRANK',
#  'BROWN, LAURA',
#  'BROWN, MINDY MCPHERS',
#  'BROWSER',
#  'BRUKNER, DR. FRANK',
#  'BRUKNER, ILANEY',
#  'BRUNNHILDE/MCM-XLI (',
#  'BRUNO',
#  'BRUTACUS',
#  'BRUTE II/',
#  'BRUTE | MUTANT X-VER',
#  'BRUTE/REED RICHARDS ',
#  'BRUTO THE STRONGMAN/',
#  'BRUTUS',
#  'BRUTUS II',
#  'BRUTUS KLOR',
#  'BRYCE, ARCHER',
#  'BUCHANAN, SAM',
#  'BUCHETTO, SALVATORE ',
#  'BUCHOVITZ, STANLEY &',
#  'BUCKMAN, EDWARD',
#  'BUCKNER, GRANT',
#  'BUCKY II/FRED DAVIS',
#  'BUCKY VI/',
#  'BUCKY VII/RIKKI BARN',
#  'BUCKY/BUCKY BARNES',
#  'BUEL',
#  'BUG',
#  'BUKOWSKI, BUCK',
#  'BULL',
#  'BULLDOZER/HENRY CAMP',
#  'BULLET',
#  'BULLET BIKER',
#  'BULLSEYE',
#  'BULLSEYE II/BENJAMIN',
#  'BULLSEYE | MUTANT X-',
#  'BULWARK/',
#  'BUMPKIN',
#  'BUMPO, MR.',
#  'BUNYAN, PAUL',
#  'BURGOS, CARL',
#  'BURKE',
#  'BURKE, GWYNETH',
#  'BURKE, JACK',
#  'BURKE, JOB',
#  'BURKE, RICKY',
#  'BURKE, THERESA TRACY',
#  'BURLEY, MIKE',
#  'BURLINGAME, CALVIN',
#  'BURNING PUDDLE',
#  'BURR, CLAYTON',
#  'BURRTHROP, T. BARTON',
#  'BURST/',
#  'BUSH, GEORGE',
#  'BUSHKIN, BARNEY',
#  'BUSHMAN, RAOUL',
#  'BUSHMASTER II/QUINCY',
#  'BUSHMASTER/JOHN MCIV',
#  'BUSHWACKER/CARL',
#  'BUSIEK, KURT',
#  'BUTCH',
#  'BUTTERFLY',
#  'BUTTONS',
#  'BUX',
#  'BUZZ',
#  'BUZZARD',
#  'BYRD, NATHANIEL ALEX',
#  'BYRD, SEN. HARRINGTO',
#  'BYREL',
#  'BYRNE, JOHN',
#  'BYRNES, GAYLE WATSON',
#  'BYRNES, TIM',
#  'BYRRAH [ATLANTEAN]',
#  'BYRRAH | HEROES REBO',
#  'C.F.',
#  'CABE, BETHANY',
#  'CABER',
#  'CACHE',
#  'CACHES, FABIAN',
#  'CACHES, PROF. MARINA',
#  'CACTUS',
#  'CADAVER',
#  'CADMIUM',
#  'CADUCEUS',
#  'CAESAR',
#  'CAESAR, JONATHAN',
#  'CAESAR, JULIUS',
#  'CAGE, LUKE/CARL LUCA',
#  'CAGLIOSTRO, ALESSAND',
#  'CAIRN, DET.',
#  'CALCULUS/JAHAHAREL P',
#  'CALDERONE, HANNAH',
#  'CALDRONE, JAVIER',
#  'CALEDONIA/ALISANDE S',
#  'CALIBAN/',
#  'CALIFORNIUM',
#  'CALKIN, SUSAN',
#  'CALLAGHAN, JAMES',
#  'CALLAHAN, MIKE',
#  'CALLISTO',
#  'CALLISTO | MUTANT X-',
#  'CALUMET',
#  'CALYPSO',
#  'CAMBRIDGE, MOXIE',
#  'CAMPBELL, DR. RORY',
#  'CAMPBELL, MEREDITH',
#  'CAMPBELL, VALERIE',
#  'CANCELLATOR',
#  'CANCER II/',
#  'CANCER/JACK KLEVENO',
#  'CANDLEMAS/',
#  'CANDLER, OWEN',
#  'CANDRA',
#  'CANDY',
#  'CANE/',
#  'CANNONBALL II/SAM GU',
#  'CANNONBALL/JACK PULV',
#  'CANNONBALL/SAM GUTHR',
#  'CANTOR, VERA',
#  'CAPRICORN II/',
#  'CAPRICORN/WILLARD WE',
#  'CAPTAIN AMERICA',
#  'CAPTAIN AMERICA DOPP',
#  'CAPTAIN AMERICA IV/S',
#  'CAPTAIN AMERICA V/RO',
#  'CAPTAIN AMERICA | MU',
#  'CAPTAIN BARRACUDA',
#  'CAPTAIN BRITAIN 2013',
#  'CAPTAIN BRITAIN/BRIA',
#  'CAPTAIN FATE',
#  'CAPTAIN GLORY',
#  'CAPTAIN HAWK',
#  'CAPTAIN HIP/FRED MAC',
#  'CAPTAIN MANHATTAN',
#  'CAPTAIN MARVEL II/MO',
#  'CAPTAIN MARVEL III/G',
#  'CAPTAIN MARVEL/CAPTA',
#  'CAPTAIN POWER/DR. CH',
#  'CAPTAIN RECTITUDE',
#  'CAPTAIN TERROR/DAN K',
#  'CAPTAIN U.K./LINDA M',
#  'CAPTAIN ULTRA/GRIFFI',
#  'CAPTAIN UNIVERSE/STE',
#  'CAPTAIN WINGS/',
#  'CAPUTO, DR. JULIA',
#  'CARBON',
#  'CARBONE, JULIUS',
#  'CARBONE, ROSALIE',
#  'CARBONE, SALVATORE',
#  'CARDENAS, PACO',
#  'CARDIAC/DR. ELI WIRT',
#  'CARDINAL/CLEMDENON',
#  'CARDINALE, CARLOS',
#  'CAREGIVER/RUBANNA LA',
#  'CARETAKER',
#  'CARGIL/JOANNA CARGIL',
#  'CARGO',
#  'CARINA/CARINA WALTER',
#  'CARLISLE, JENNA',
#  'CARLISLE, MELISSA BO',
#  'CARLISLE, PHILLIP',
#  'CARLTON, JAKE',
#  'CARLTON, LUCY',
#  'CARLY',
#  'CARMODY, MARY',
#  'CARMODY, MRS.',
#  'CARNAGE/CLETUS KASAD',
#  'CARNIVORE/COUNT ANDR',
#  'CARPATHIAN, ANDREW',
#  'CARPENTER, LARRY',
#  'CARPENTER, RACHEL',
#  'CARR, DAN',
#  'CARRADINE, JESSICA J',
#  'CARRERA, MIA',
#  'CARRION',
#  'CARRION II/MALCOLM M',
#  'CARRION III/DR. WILL',
#  'CARSON, LT. PAUL',
#  'CARTER, BRAD',
#  'CARTER, JIMMY',
#  'CARTER, PEGGY',
#  'CARTER, SHARON',
#  'CARTER, SHARON II',
#  'CARTER, TAD',
#  'CARTHUS',
#  'CARVER',
#  'CASE, COL. PRESTON',
#  'CASEY',
#  'CASIOLENA, QUEEN',
#  'CASPER',
#  'CASS, LARRY MAD DOG',
#  'CASSADA, CARLOS',
#  'CASSADA, MICHAEL',
#  'CASSADA, ROBERTO',
#  'CASSADA, ROSA',
#  'CASSANDRA',
#  'CASSIOPEIA',
#  'CAT BURGLAR',
#  'CAT II',
#  'CAT III/SHEN KUEI',
#  'CAT IV',
#  'CAT KING',
#  'CAT MAN III/',
#  'CAT MAN/HORGAN',
#  'CATAPHRAX',
#  'CATHERWOOD',
#  'CATHODE/',
#  'CATSEYE/SHARON SMITH',
#  'CATWALK/KIMBERLY DEE',
#  'CAULDER, SAFRON',
#  'CEAUSECU, IONEL',
#  'CELESTE',
#  'CELLANOS, MARCELLA',
#  'CENTARIUS',
#  'CENTURIUS',
#  'CENTURY',
#  'CENTURY, TURNER D.',
#  'CERA, KAY',
#  'CERANDA',
#  'CERBERUS',
#  'CERBERUS II',
#  'CEREBRITE ALPHA',
#  'CEREBRITE BETA',
#  'CEREBRO',
#  'CEREBRO MARK XIII | ',
#  'CEREBRO | MUTANT-X V',
#  'CERISE',
#  "CERISE II [SHI'AR]",
#  'CESIUM',
#  'CETHLANN',
#  "CH'OD",
#  "CH'THON",
#  "CH'VAYRE",
#  'CHADWICK, CHEER',
#  'CHADWICK, DR. HESPER',
#  'CHAIN',
#  'CHAINSAW/',
#  'CHAKA KHAN',
#  'CHAKA KHAN II',
#  'CHAKARA, KANU',
#  'CHAKARA, MADAN',
#  'CHAKRA',
#  'CHAKRA II',
#  'CHALIZ, HAZRAM',
#  'CHALIZ, SHANAZ RAYNA',
#  'CHALIZ, TABRIAZ',
#  'CHALKER, PROF. VIC',
#  'CHALMER, JUDGE',
#  'CHALMERS, CYNTHIA',
#  'CHALMERS, JUDGE ROBE',
#  'CHALMERS, MR.',
#  'CHAMBER/JONOTHON STA',
#  'CHAMBERS, MR.',
#  'CHAMBLISS',
#  'CHAMELEON/DMITRI SME',
#  'CHAMPION, IMUS',
#  'CHAMPION/TRYCO SLATT',
#  'CHAN, SARAH',
#  'CHANCE',
#  'CHANCE II/NICHOLAS P',
#  'CHANDLER, PEGGY',
#  'CHANDRA, DR.',
#  'CHANEY, AMANDA',
#  'CHANG, DR. PHILLIP',
#  'CHANG, IMEI',
#  'CHANGELING',
#  'CHAOS/DANIEL DASH',
#  ...]
